# %%
import papermill as pm

# %%
ym = '202309'

# %%
# Execute mart 1
pm.execute_notebook(
    './run_all_1.ipynb',
    f'./run_all_1_{ym}.ipynb',
    parameters = dict(ym = ym)
)
# Out:
# Executing: 100%|██████████| 5/5 [00:03<00:00,  1.33cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2023-09-20T04:22:43.437297',
#      'end_time': '2023-09-20T04:22:43.454449',
#      'duration': 0.017152,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2023-09-20T04:22:43.449225Z',
#      'iopub.execute_input': '2023-09-20T04:22:43.449225Z',
#      'shell.execute_reply': '2023-09-20T04:22:43.454449Z',
#      'iopub.status.idle': '2023-09-20T04:22:43.454449Z'}},
#    'outputs': [],
#    'source': "# parameters\nym = '999999'",
#    'id': '19f7925f'},
#   {'id': '1a517095',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2023-09-20T04:22:43.456408',
#      'end_time': '2023-09-20T04:22:43.469962',
#      'duration': 0.013554,
# ...

# %%
# Execute mart 2
pm.execute_notebook(
    './run_all_2.ipynb',
    f'./run_all_2_{ym}.ipynb',
    parameters = dict(ym = ym)
)
# Out:
# Executing: 100%|██████████| 5/5 [00:03<00:00,  1.37cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2023-09-20T04:22:47.188539',
#      'end_time': '2023-09-20T04:22:47.204673',
#      'duration': 0.016134,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2023-09-20T04:22:47.193437Z',
#      'iopub.execute_input': '2023-09-20T04:22:47.194435Z',
#      'iopub.status.idle': '2023-09-20T04:22:47.204673Z',
#      'shell.execute_reply': '2023-09-20T04:22:47.204673Z'}},
#    'outputs': [],
#    'source': "# parameters\nym = '999999'",
#    'id': '5a99a070'},
#   {'id': '7deb93ab',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2023-09-20T04:22:47.206652',
#      'end_time': '2023-09-20T04:22:47.220131',
#      'duration': 0.013479,
# ...
